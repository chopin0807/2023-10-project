# %%
# 2022.01-2022.12
import pandas as pd
import requests
from bs4 import BeautifulSoup
import re

# %%
# 원할한 기사 크롤링을 위한 가이드 코드임
# 네이버에서 검색어를 "카카오"(큰 따옴표 포함)로 하고, 2022년 1월 2일 기사에 대해서 기사제목, 기사내용에 대해서 크롤링함
url = 'https://search.naver.com/search.naver?where=news&query=%22%EC%B9%B4%EC%B9%B4%EC%98%A4%22&sm=tab_opt&sort=0&photo=0&field=0&pd=3&ds=2022.12.31&de=2022.01.02&docid=&related=0&mynews=0&office_type=0&office_section_code=0&news_office_checked=&nso=so%3Ar%2Cp%3Afrom20220102to20221231&is_sug_officeid=0&office_category=0&service_area=0'
headers = {'User-Agent':'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/118.0.0.0 Safari/537.36'}
res = requests.get(url, headers=headers)
soup = BeautifulSoup(res.text, 'html.parser')
soup

# %%
# 기사 제목, 기사 내용을 크롤링함
# 기사 제목은 위 사이트에서 바로 진행 가능하나, 기사 내용은 '네이버 뉴스'링크로 들어가서 기사 내용을 크롤링함
# 네이버 뉴스 링크가 없는 기사는 기사 내용에 대해 None처리함
title = soup.select('div.news_contents > a.news_tit')
title

# %%
# 기자 제목 추출
title[0]['title']
# Out:
# "'전례없는 무료서비스 보상' 카카오, 상생 약속 지켰다(종합)"

# %%
title_list = [] # 기자제목 리스트
for i in title:
  title_list.append(i['title'])
title_list
# Out:
# ["'전례없는 무료서비스 보상' 카카오, 상생 약속 지켰다(종합)",
#  '카카오 먹통 사태 6000억 통큰 결단, 전례 없는 무료 서비스 보상',
#  "카카오, '장애' 피해 소상공인 최대 5만원…일반 이용자도 보상(종합)",
#  '‘집콕족’ 줄고 다시 공항·쇼핑몰로…카카오내비 결산 데이터 공개',
#  '"삼전 8층 주주님이 등장하셨다"…카카오 종토방에 무슨 일이 [인터뷰+]',
#  "카카오 먹통 보상 '3~5만원·이모티콘'에 소상공인들 불만",
#  '[넘버스]카카오에게 보상액 수천억원보다 중요한 것',
#  '카카오뱅크, 청소년 예체능 활동 지원 1억 기부',
#  '카카오 택시 부를 때 개인정보 노출 문제 없나요?',
#  "정부, 플랫폼 독점규제+자율규제 투트랙…'카카오 먹통' 후폭풍?"]

# %%
# 기사 본문 추출을 위한 네이버 기사 링크 찾기
naver_article = soup.select('div.info_group')
naver_article

# %%
article_list = []
for i in naver_article:
  article_list.append(i)
article_list[0]
# Out:
# <div class="info_group"> <a class="info press" href="http://www.newsis.com" onclick="return goOtherCR(this, 'a=nws*h.prof&amp;r=1&amp;i=88000127_000000000000000011617634&amp;g=003.0011617634&amp;u='+urlencode(this.href));" target="_blank"><span class="thumb_box"><img alt="" class="thumb" data-lazysrc="https://search.pstatic.net/common/?src=https%3A%2F%2Fmimgnews.pstatic.net%2Fimage%2Fupload%2Foffice_logo%2F003%2F2019%2F02%2F19%2Flogo_003_18_20190219111719.jpg&amp;type=f54_54&amp;expire=24&amp;refresh=true" height="24" onerror="this.src='...';this.className='thumb bg_default_press'" src="..." width="24"/></span>뉴시스<i class="spnew ico_pick">언론사 선정</i></a><span class="info">2022.12.29.</span><a class="info" href="https://n.news.naver.com/mnews/article/003/0011617634?sid=105" onclick="return goOtherCR(this, 'a=nws*h.nav&amp;r=1&amp;i=88000127_000000000000000011617634&amp;u='+urlencode(this.href));" target="_blank">네이버뉴스</a> </div>

# %%
article_list[1]
# Out:
# <div class="info_group"> <a class="info press" href="http://biz.chosun.com/" onclick="return goOtherCR(this, 'a=nws*h.prof&amp;r=6&amp;i=88127058_000000000000000000866170&amp;g=366.0000866170&amp;u='+urlencode(this.href));" target="_blank"><span class="thumb_box"><img alt="" class="thumb" data-lazysrc="https://search.pstatic.net/common/?src=https%3A%2F%2Fmimgnews.pstatic.net%2Fimage%2Fupload%2Foffice_logo%2F366%2F2017%2F01%2F05%2Flogo_366_18_20170105111205.png&amp;type=f54_54&amp;expire=24&amp;refresh=true" height="24" onerror="this.src='...';this.className='thumb bg_default_press'" src="..." width="24"/></span>조선비즈<i class="spnew ico_pick">언론사 선정</i></a><span class="info">2022.12.30.</span><a class="info" href="https://n.news.naver.com/mnews/article/366/0000866170?sid=105" onclick="return goOtherCR(this, 'a=nws*h.nav&amp;r=6&amp;i=88127058_000000000000000000866170&amp;u='+urlencode(this.href));" target="_blank">네이버뉴스</a> </div>

# %%
article_list[0].select('a')[0]['href'] # 언론사별 기사링크
# Out:
# 'http://www.newsis.com'

# %%
article_list[0].select('a')[1]['href'] # 네이버뉴스 링크 => 링크가 없다면 이 코드는 작동하지 않음 => try except 방식으로 예외처리
# Out:
# 'https://n.news.naver.com/mnews/article/003/0011617634?sid=105'

# %%
article_list[1].select('a')[0]['href']
# Out:
# 'http://biz.chosun.com/'

# %%
article_list[1].select('a')[1]['href']
# Out:
# 'https://n.news.naver.com/mnews/article/366/0000866170?sid=105'

# %%
# 네이버 기사 링크 리스트로 정리
naver_article_url = []
for i in article_list:
  try:
    naver_article_url.append(i.select('a')[1]['href'])
  except:
    naver_article_url.append('url없음')
naver_article_url
# Out:
# ['https://n.news.naver.com/mnews/article/003/0011617634?sid=105',
#  'https://n.news.naver.com/mnews/article/366/0000866170?sid=105',
#  'https://n.news.naver.com/mnews/article/001/0013671035?sid=105',
#  'https://n.news.naver.com/mnews/article/243/0000037282?sid=105',
#  'https://n.news.naver.com/mnews/article/015/0004794021?sid=101',
#  'https://n.news.naver.com/mnews/article/448/0000389002?sid=101',
#  'https://n.news.naver.com/mnews/article/293/0000041972?sid=105',
#  'https://n.news.naver.com/mnews/article/003/0011618228?sid=101',
#  'https://n.news.naver.com/mnews/article/374/0000316436?sid=103',
#  'https://n.news.naver.com/mnews/article/003/0011616070?sid=105']

# %%
# 기사 날짜 추출
date = soup.select('div.info_group > span')
date_list = []
for i in date:
  date_list.append(i.text)
date_list
# Out:
# ['2022.12.29.',
#  '2022.12.30.',
#  '2022.12.29.',
#  '2022.12.30.',
#  '2022.12.31.',
#  '2022.12.30.',
#  '2022.12.30.',
#  '2022.12.30.',
#  '2022.12.29.',
#  '2022.12.29.']

# %%
# 날짜형식(xxxx.xx.xx.)이 나오게 수정
article_date = []
for i in date_list:
  p = re.compile('[0-9][0-9][0-9][0-9].[0-9][0-9].[0-9][0-9].')
  if p.match(i) != None:
    article_date.append(i)
article_date
# Out:
# ['2022.12.29.',
#  '2022.12.30.',
#  '2022.12.29.',
#  '2022.12.30.',
#  '2022.12.31.',
#  '2022.12.30.',
#  '2022.12.30.',
#  '2022.12.30.',
#  '2022.12.29.',
#  '2022.12.29.']

# %%
# 기사 날짜 기사제목과 네이버 뉴스 url을 dataframe으로 정리
df_dic = {'기사날짜': article_date, '기사제목': title_list, '네이버 뉴스 url': naver_article_url}
df = pd.DataFrame(df_dic)
df
# Out:
#           기사날짜                                      기사제목  \
# 0  2022.12.29.        '전례없는 무료서비스 보상' 카카오, 상생 약속 지켰다(종합)
# 1  2022.12.30.    카카오 먹통 사태 6000억 통큰 결단, 전례 없는 무료 서비스 보상
# 2  2022.12.29.   카카오, '장애' 피해 소상공인 최대 5만원…일반 이용자도 보상(종합)
# 3  2022.12.30.       ‘집콕족’ 줄고 다시 공항·쇼핑몰로…카카오내비 결산 데이터 공개
# 4  2022.12.31.  "삼전 8층 주주님이 등장하셨다"…카카오 종토방에 무슨 일이 [인터뷰+]
# 5  2022.12.30.          카카오 먹통 보상 '3~5만원·이모티콘'에 소상공인들 불만
# 6  2022.12.30.               [넘버스]카카오에게 보상액 수천억원보다 중요한 것
# 7  2022.12.30.                카카오뱅크, 청소년 예체능 활동 지원 1억 기부
# 8  2022.12.29.               카카오 택시 부를 때 개인정보 노출 문제 없나요?
# 9  2022.12.29.       정부, 플랫폼 독점규제+자율규제 투트랙…'카카오 먹통' 후폭풍?
#
#                                           네이버 뉴스 url
# 0  https://n.news.naver.com/mnews/article/003/001...
# 1  https://n.news.naver.com/mnews/article/366/000...
# 2  https://n.news.naver.com/mnews/article/001/001...
# 3  https://n.news.naver.com/mnews/article/243/000...
# 4  https://n.news.naver.com/mnews/article/015/000...
# 5  https://n.news.naver.com/mnews/article/448/000...
# 6  https://n.news.naver.com/mnews/article/293/000...
# 7  https://n.news.naver.com/mnews/article/003/001...
# 8  https://n.news.naver.com/mnews/article/374/000...
# 9  https://n.news.naver.com/mnews/article/003/001...
