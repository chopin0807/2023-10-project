# %%
# 구글 드라이브 마운트
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pip install konlpy
# Out:
# Collecting konlpy
#   Downloading konlpy-0.6.0-py2.py3-none-any.whl (19.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 19.4/19.4 MB 45.8 MB/s eta 0:00:00
# Collecting JPype1>=0.7.0 (from konlpy)
#   Downloading JPype1-1.4.1-cp310-cp310-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (465 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 465.3/465.3 kB 28.2 MB/s eta 0:00:00
# Requirement already satisfied: lxml>=4.1.0 in /usr/local/lib/python3.10/dist-packages (from konlpy) (4.9.3)
# Requirement already satisfied: numpy>=1.6 in /usr/local/lib/python3.10/dist-packages (from konlpy) (1.23.5)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from JPype1>=0.7.0->konlpy) (23.2)
# Installing collected packages: JPype1, konlpy
# Successfully installed JPype1-1.4.1 konlpy-0.6.0

# %%
import pandas as pd
from konlpy.tag import Okt
from tqdm import tqdm, tqdm_pandas

tqdm.pandas()

# %%
# 강사님으로부터 받은 2021년 기사 데이터 확인
df = pd.read_csv('/content/drive/MyDrive/2023년 10월-11월 프로젝트/카카오 기사데이터/요청데이터/카카오_2021-01-01_2021-12-31.csv')
df
# Out:
#        Unnamed: 0                 date  media  \
# 0               0  2021-09-23T05:31:00   이데일리
# 1               1  2021-09-14T20:42:00  헤럴드경제
# 2               2  2021-01-19T16:54:00  머니투데이
# 3               3  2021-01-19T17:24:00   데일리안
# 4               4  2021-05-08T08:22:00   한국경제
# ...           ...                  ...    ...
# 50455       50455  2021-01-25T04:30:00   한국일보
# 50456       50456  2021-03-25T18:33:00    KBS
# 50457       50457  2021-11-22T00:14:00    KBS
# 50458       50458  2021-03-03T21:09:00    KBS
# 50459       50459  2021-12-22T16:39:00    SBS
#
#                                                      url category  \
# 0      https://news.naver.com/main/read.naver?mode=LS...       정치
# 1      https://news.naver.com/main/read.naver?mode=LS...    IT/과학
# 2      https://news.naver.com/main/read.nhn?mode=LS2D...    IT/과학
# 3      https://news.naver.com/main/read.nhn?mode=LS2D...    IT/과학
# 4      https://news.naver.com/main/read.naver?mode=LS...    IT/과학
# ...                                                  ...      ...
# 50455  https://news.naver.com/main/read.nhn?mode=LS2D...       사회
# 50456  https://news.naver.com/main/read.naver?mode=LS...       경제
# 50457  https://news.naver.com/main/read.naver?mode=LS...       정치
# 50458  https://news.naver.com/main/read.naver?mode=LS...       경제
# 50459  https://news.naver.com/main/read.naver?mode=LS...       정치
#
#       category_sub                                              title  \
# 0            국회/정당                 [단독]카카오T 가맹택시 콜 하루평균 10회, 일반택시는 4회
# 1            IT 일반                   “욕하면서도 쓸 수밖에 없다”…카카오T ‘대체 불가’ 왜?
# 2          인터넷/SNS                             카카오VX, 골프존 특허침해 항소심 승소
# 3            IT 일반                          카카오VX, 골프존 특허침해 항소심서 ‘승소’
# 4            IT 일반              카카오, OTT 포기하고 제작사로? 이유 있는 오해 [연예 마켓+]
# ...            ...                                                ...
# 50455           노동                 [중간착취의 지옥도] 노동의 대가를 도둑맞은 100명의 이야기
# 50456        경제 일반                      [박종훈의 경제한방] 증시 조정장에 대처하는 방법은?
# 50457         정치일반       [질문하는 기자들Q] 대선 후보 ‘언론 정책’ 긴급 점검, 언론 개혁은 어떻게?
# 50458        경제 일반  [주진우 라이브] 도올 김용옥 “우린 이미 식량주권상실, 농촌 공동체 살려 식량주권...
# 50459         정치일반               이재명 '김문기 사망' 안타까워…양도세 1년만 유예 후 다시 중과
#
#                                                  content
# 0      카카오T 10번 호출시 2번은 카카오T블루 전체 15% 불과한 카카오T블루 일평균 ...
# 1      "독점 갑질 논란 알지만  '넘사벽(넘을 수 없는 4차원의 벽)'인 걸 어쩌나" 카...
# 2      카카오VX는 골프존이 제기한 특허침해소송 항소심 판결에서 승소했다고 19일 밝혔다....
# 3      골프 시뮬레이터 특허 기술 침해 논란 종결 카카오VX는 골프존이 제기한 특허침해소송...
# 4      넷플릭스 웨이브 KBS에서 보는 카카오TV 오리지널 '구독' 서비스 OTT 플랫폼과...
# ...                                                  ...
# 50455  당신은 힘들게 일하는 노동자입니다. 피 땀 눈물의 대가로 월급을 받지요. 그런데 누...
# 50456  출연  염승환 이베스트 투자증권 부장 녹화  3월 23일  개인의 '지수 반대로 매...
# 50457  방송 내용과 차이가 있을 수 있습니다. 정확한 내용은 영상을 통해 확인해주세요 1....
# 50458  인터뷰 자료의 저작권은 라디오에 있습니다.  전문 게재나 인터뷰 인용 보도 시,  ...
# 50459  인터뷰를 인용보도할 때는 프로그램명 ' '을 정확히 밝혀주시기 바랍니다. 저작권은 ...
#
# [50460 rows x 8 columns]

# %%
# 전처리과정
# 필요없는 속성 제거
df.drop(columns=['Unnamed: 0', 'media','category','category_sub'],inplace=True)
df.reset_index(drop=True, inplace=True)
df
# Out:
#                       date                                                url  \
# 0      2021-09-23T05:31:00  https://news.naver.com/main/read.naver?mode=LS...
# 1      2021-09-14T20:42:00  https://news.naver.com/main/read.naver?mode=LS...
# 2      2021-01-19T16:54:00  https://news.naver.com/main/read.nhn?mode=LS2D...
# 3      2021-01-19T17:24:00  https://news.naver.com/main/read.nhn?mode=LS2D...
# 4      2021-05-08T08:22:00  https://news.naver.com/main/read.naver?mode=LS...
# ...                    ...                                                ...
# 50455  2021-01-25T04:30:00  https://news.naver.com/main/read.nhn?mode=LS2D...
# 50456  2021-03-25T18:33:00  https://news.naver.com/main/read.naver?mode=LS...
# 50457  2021-11-22T00:14:00  https://news.naver.com/main/read.naver?mode=LS...
# 50458  2021-03-03T21:09:00  https://news.naver.com/main/read.naver?mode=LS...
# 50459  2021-12-22T16:39:00  https://news.naver.com/main/read.naver?mode=LS...
#
#                                                    title  \
# 0                     [단독]카카오T 가맹택시 콜 하루평균 10회, 일반택시는 4회
# 1                       “욕하면서도 쓸 수밖에 없다”…카카오T ‘대체 불가’ 왜?
# 2                                 카카오VX, 골프존 특허침해 항소심 승소
# 3                              카카오VX, 골프존 특허침해 항소심서 ‘승소’
# 4                  카카오, OTT 포기하고 제작사로? 이유 있는 오해 [연예 마켓+]
# ...                                                  ...
# 50455                 [중간착취의 지옥도] 노동의 대가를 도둑맞은 100명의 이야기
# 50456                      [박종훈의 경제한방] 증시 조정장에 대처하는 방법은?
# 50457       [질문하는 기자들Q] 대선 후보 ‘언론 정책’ 긴급 점검, 언론 개혁은 어떻게?
# 50458  [주진우 라이브] 도올 김용옥 “우린 이미 식량주권상실, 농촌 공동체 살려 식량주권...
# 50459               이재명 '김문기 사망' 안타까워…양도세 1년만 유예 후 다시 중과
#
#                                                  content
# 0      카카오T 10번 호출시 2번은 카카오T블루 전체 15% 불과한 카카오T블루 일평균 ...
# 1      "독점 갑질 논란 알지만  '넘사벽(넘을 수 없는 4차원의 벽)'인 걸 어쩌나" 카...
# 2      카카오VX는 골프존이 제기한 특허침해소송 항소심 판결에서 승소했다고 19일 밝혔다....
# 3      골프 시뮬레이터 특허 기술 침해 논란 종결 카카오VX는 골프존이 제기한 특허침해소송...
# 4      넷플릭스 웨이브 KBS에서 보는 카카오TV 오리지널 '구독' 서비스 OTT 플랫폼과...
# ...                                                  ...
# 50455  당신은 힘들게 일하는 노동자입니다. 피 땀 눈물의 대가로 월급을 받지요. 그런데 누...
# 50456  출연  염승환 이베스트 투자증권 부장 녹화  3월 23일  개인의 '지수 반대로 매...
# 50457  방송 내용과 차이가 있을 수 있습니다. 정확한 내용은 영상을 통해 확인해주세요 1....
# 50458  인터뷰 자료의 저작권은 라디오에 있습니다.  전문 게재나 인터뷰 인용 보도 시,  ...
# 50459  인터뷰를 인용보도할 때는 프로그램명 ' '을 정확히 밝혀주시기 바랍니다. 저작권은 ...
#
# [50460 rows x 4 columns]

# %%
# 날짜 기준으로 정렬
df = df.sort_values(by=['date'])
df.reset_index(drop=True, inplace=True)
df
# Out:
#                       date                                                url  \
# 0      2021-01-01T02:20:00  https://news.naver.com/main/read.nhn?mode=LS2D...
# 1      2021-01-01T03:37:00  https://news.naver.com/main/read.nhn?mode=LS2D...
# 2      2021-01-01T04:30:00  https://news.naver.com/main/read.nhn?mode=LS2D...
# 3      2021-01-01T04:44:00  https://news.naver.com/main/read.nhn?mode=LS2D...
# 4      2021-01-01T06:01:00  https://news.naver.com/main/read.nhn?mode=LS2D...
# ...                    ...                                                ...
# 50455  2021-12-31T20:00:00  https://news.naver.com/main/read.naver?mode=LS...
# 50456  2021-12-31T20:03:00  https://news.naver.com/main/read.naver?mode=LS...
# 50457  2021-12-31T21:20:00  https://news.naver.com/main/read.naver?mode=LS...
# 50458  2021-12-31T23:03:00  https://news.naver.com/main/read.naver?mode=LS...
# 50459  2021-12-31T23:52:00  https://news.naver.com/main/read.naver?mode=LS...
#
#                                              title  \
# 0                 1월효과, 연말랠리 잇는다…증권가 실적개선·경기민감株 주목
# 1            네이버·카카오 추천뉴스, 사실 여부보다 더 많은 클릭받을 기사 골라
# 2                      [새해증시]자녀에게 물려줄 주식은 삼성전자·테슬라
# 3             '올해 가장 유망한 주식' 1위 삼성전자, 2위 현대차[새해증시]
# 4              [2021 전망-인터넷] 韓 인터넷 세계로…규제 강화는 '숙제'
# ...                                            ...
# 50455  1~3세대 실손보험료 평균 14% 인상…갱신주기 맞은 가입자 체감 30% 이상
# 50456            현행 거리두기 '2주 더'…백화점 · 마트에서도 '방역패스'
# 50457            “무조건 돈 번다고 해서 믿고 샀는데” 사람들 울린 ‘이것’
# 50458           손보협 “실손 인상률 평균 14.2%”… 갱신 땐 50% 훌쩍
# 50459                           2021년, IT업계 달군 사건들
#
#                                                  content
# 0      증권가, 1월 코스피 예상밴드 2730~2990 제시 연말 주가 급등했지만 내릴 요...
# 1      네이버는 2017년 2월부터 자체 개발한 콘텐츠 추천 시스템인 'AiRS(에어스)'...
# 2      국내주식 12년 연속 삼성전자 1위  삼성전자가 13년 연속 '자녀에 물려주고 싶은...
# 3      코스피에선 현대차, SK하이닉스. 코스닥은 셀트리온헬스케어, 씨젠 등 주목  증시 ...
# 4      합종연횡으로 新성장동력 확보 세계무대 누빈다  올해 국내 인터넷 업계는 내수기업이란...
# ...                                                  ...
# 50455  50대 이상 '보험료 폭탄' 걱정 4세대 상품 전환 시 50% 할인 2017년 3월...
# 50456  거리두기 때문에 송년 모임 미룬 분들 많으실 텐데, 신년 모임도 당분간은 쉽지 않을...
# 50457  "삼성전자보다 더 좋다고 해서 샀는데 " (투자자) 네이버와 카카오가 불과 1~2년...
# 50458  2022년 새해 실손의료보험 인상률이 평균 14.2% 수준으로 결정됐다.    31...
# 50459  2022년이 코앞으로 다가왔다. 올해도 정보통신기술(ICT)업계는 다사다난했다. 코...
#
# [50460 rows x 4 columns]

# %%
# 전처리 의견 반영함
df = df[df['title'].str.contains(' 카카오 |.카카오 |,카카오 | 카카오,| 카카오.|카카오페이|카카오뱅크|카카오게임즈|카뱅|카겜',na=False)]
df.reset_index(drop=True, inplace=True)
df
# Out:
#                      date                                                url  \
# 0     2021-01-01T03:37:00  https://news.naver.com/main/read.nhn?mode=LS2D...
# 1     2021-01-01T08:00:00  https://news.naver.com/main/read.nhn?mode=LS2D...
# 2     2021-01-01T13:04:00  https://news.naver.com/main/read.nhn?mode=LS2D...
# 3     2021-01-01T13:21:00  https://news.naver.com/main/read.nhn?mode=LS2D...
# 4     2021-01-01T17:05:00  https://news.naver.com/main/read.nhn?mode=LS2D...
# ...                   ...                                                ...
# 8422  2021-12-30T14:49:00  https://news.naver.com/main/read.naver?mode=LS...
# 8423  2021-12-30T16:33:00  https://news.naver.com/main/read.naver?mode=LS...
# 8424  2021-12-30T18:02:00  https://news.naver.com/main/read.naver?mode=LS...
# 8425  2021-12-31T14:03:00  https://news.naver.com/main/read.naver?mode=LS...
# 8426  2021-12-31T15:06:00  https://news.naver.com/main/read.naver?mode=LS...
#
#                                                   title  \
# 0                 네이버·카카오 추천뉴스, 사실 여부보다 더 많은 클릭받을 기사 골라
# 1                       주식부호 '1조클럽' 25명…김범수 카카오의장 순위 껑충
# 2     2020년 '1조클럽' 25명…카카오 김범수 2.9조 늘고, 아모레 서경배 1.2조 폭락
# 3             [2021 테크체인저]⑤네이버보다 카카오?...일상을 바꿀 기업 설문 결과
# 4                            작년 매출 신기록 쓴 카카오·엔씨…올해 더 좋다
# ...                                                 ...
# 8422                       [ET뉴스 픽!]카카오 지그재그, 첫 패션PB 임박
# 8423             '상생' 외친 카카오모빌리티 일회성 아닌 지속가능한 협력 생태계 목표
# 8424                     택시기사 등 업계와 공존 카카오모빌리티 상생 길 넓힌다
# 8425       새로운 골프 시장 개척하는 게임 체인저 '카카오 VX', 디지털 골프 혁신 주도
# 8426         초기 스타트업 키우는 IT 공룡들… 네이버는 AI·메타버스, 카카오는 플랫폼
#
#                                                 content
# 0     네이버는 2017년 2월부터 자체 개발한 콘텐츠 추천 시스템인 'AiRS(에어스)'...
# 1     코스피 사상 최고 마감에 주식부자도 늘어 고 이건희 회장 지분가치 한해 6.6조원 ...
# 2     2020년 코스피 지수가 사상 최고치로 마감하면서 1조원 이상의 주식을 보유하고 있...
# 3     "네이버보단 카카오." 응답자들은 2021년 우리 일상을 바꿀 것으로 기대되는 유망...
# 4     증권사 전망치 분석 296곳 중 136곳 최대 실적 예고 카카오, 신사업 본격 성장...
# ...                                                 ...
# 8422  카카오의 온라인 패션 플랫폼 지그재그가 자체브랜드(PB) 개발에 착수한다. 패션, ...
# 8423  업계 의견 수렴해 장기 상생 구현 목표 일회성 그치지 않고 협력 기반 성장 도모 지...
# 8424  대리운전 수수료 개선 등 이어 새해에도 '상생 플랫폼' 강화 스타트업 기술고도화 지...
# 8425  코로나19 사태를 계기로 골프 산업이 MZ 세대뿐 아니라 전 세대에서 각광을 받으며...
# 8426  네이버 카카오 투자한 초기 스타트업 50개사 보니 네이버는 27곳 중 9곳이 AI ...
#
# [8427 rows x 4 columns]

# %%
# 토큰화 및 불용어 처리
def TokenStopword(text):
  okt = Okt()
  okt_tokens = okt.morphs(str(text))
  oktTag = []
  for token in okt_tokens:
    oktTag += Okt().pos(token)
  # 불용어 처리
  stopPos = ['Josa', 'Punctuation', 'Suffix', 'Foreign', 'Alpha', 'Number']
  stopWord = ['연합뉴스','기자','앵커','이데일리','헤럴드','헤럴드경제','뉴스1','세계일보','서울경제'
  ,'파이낸셜','파이낸셜뉴스','이코노미스트','아이뉴스','뉴시스','동아일보','일보','조선일보','중앙일보','디지털뉴스부','인턴기자'
  ,'마이데일리','데일리안','조선비즈','한겨레','지디넷코리아','리포트','한국일보','비즈워치','한', '다', '는', '가', '도', '로']
  stopNoun = ['이', '은', '을', '를'] # '이', '은', '을', '를'은 품사가 'Noun'임
  stopLDA2021 = ['경','즈','널','해야','뒤','식','안','하는','위','초','등','남궁훈','조계','박지윤','조수용','박하선','이경규','유재석'
  ,'','총','분','상','의','오','여','어','주','내년','네','며느','영진','것','익','톡','스케','류영준','강호동','윤영','','뷰','웹','회'
  ,'민수','넘게','할','액','지','터','존','잔','퀵','그','앱','거대','부터','때'] # LDA모델 실행후 제외해야 할 것으로 생각되는 단어를 리스트에 추가해야함!!!
  stopLDA2022 = ['기','이해진','조','전','건','정','소','대','전','홍은택','하는','승','이종호','싶다면','보고','더','년','메','분기','춘'
  ,'료','지','과','고개','근','순','폰','한상혁']
  stopLDA2023 = ['했다','톡','사','아','영','와','구','개월','또','임','형','자','계','합니다','스케','현','장','개','첫','들','오늘','날'
  ,'김','차','겸']
  word = []
  for tag in oktTag:
    if tag[1] in stopPos: # 무조건 제외
      continue
    elif tag[0] in stopWord:
      continue
    elif tag[0] in stopNoun and (tag[1] == 'Noun' or tag[1] == 'Verb' or tag[1] == 'Adverb'):
      continue
    elif tag[0] in stopLDA2021:
      continue
    elif tag[0] in stopLDA2022:
      continue
    elif tag[0] in stopLDA2023:
      continue
    else:
      word.append(tag[0])
  return word

# %%
df['tokenize_title'] = df['title'].progress_apply(TokenStopword)
df['tokenize_content'] = df['content'].progress_apply(TokenStopword)
# Out:
# 100%|██████████| 8427/8427 [01:08<00:00, 123.76it/s]
# <ipython-input-9-eae70ea6eca8>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['tokenize_title'] = df['title'].progress_apply(TokenStopword)
# 100%|██████████| 8427/8427 [27:50<00:00,  5.04it/s]
# <ipython-input-9-eae70ea6eca8>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['tokenize_content'] = df['content'].progress_apply(TokenStopword)

# %%
df.drop(columns=['title','content'],inplace=True)
df.reset_index(drop=True, inplace=True)
df
# Out:
# <ipython-input-10-36e5bca442b6>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.drop(columns=['title','content'],inplace=True)
#                      date                                                url  \
# 0     2021-01-01T03:37:00  https://news.naver.com/main/read.nhn?mode=LS2D...
# 1     2021-01-01T08:00:00  https://news.naver.com/main/read.nhn?mode=LS2D...
# 2     2021-01-01T13:04:00  https://news.naver.com/main/read.nhn?mode=LS2D...
# 3     2021-01-01T13:21:00  https://news.naver.com/main/read.nhn?mode=LS2D...
# 4     2021-01-01T17:05:00  https://news.naver.com/main/read.nhn?mode=LS2D...
# ...                   ...                                                ...
# 8422  2021-12-30T14:49:00  https://news.naver.com/main/read.naver?mode=LS...
# 8423  2021-12-30T16:33:00  https://news.naver.com/main/read.naver?mode=LS...
# 8424  2021-12-30T18:02:00  https://news.naver.com/main/read.naver?mode=LS...
# 8425  2021-12-31T14:03:00  https://news.naver.com/main/read.naver?mode=LS...
# 8426  2021-12-31T15:06:00  https://news.naver.com/main/read.naver?mode=LS...
#
#                                          tokenize_title  \
# 0     [네이버, 카카오, 추천, 뉴스, 사실, 여부, 보다, 많은, 클릭, 받을, 기사,...
# 1                 [주식, 부호, 클럽, 명, 김범수, 카카오, 의장, 순위, 껑충]
# 2               [클럽, 명, 카카오, 김범수, 늘, 고, 아모레, 서, 경배, 폭락]
# 3         [테크, 체인, 저, 네이버, 보다, 카카오, 일상, 바꿀, 기업, 설문, 결과]
# 4                     [작년, 매출, 신기록, 쓴, 카카오, 엔씨, 올해, 좋다]
# ...                                                 ...
# 8422                         [뉴스, 픽, 카카오, 지그재그, 패션, 임박]
# 8423  [상생, 외친, 카카오, 모빌리티, 일, 성, 아닌, 지속, 가능한, 협력, 생태계...
# 8424            [택시, 기사, 업계, 공존, 카카오, 모빌리티, 상생, 길, 넓힌다]
# 8425  [새로운, 골프, 시장, 개척, 게임, 체인, 저, 카카오, 디지털, 골프, 혁신,...
# 8426         [초기, 스타트업, 키우는, 공룡, 네이버, 메타, 버스, 카카오, 플랫폼]
#
#                                        tokenize_content
# 0     [네이버, 자체, 개발, 콘텐츠, 추천, 시스템, 인, 어스, 뉴스, 추천, 적용,...
# 1     [코스피, 사상, 최고, 마감, 주식, 부자, 늘어, 고, 이건희, 회장, 가치, ...
# 2     [코스피, 지수, 사상, 최고, 치, 마감, 하면서, 이상, 주식, 보유, 하고, ...
# 3     [네이버, 카카오, 응답, 우리, 일상, 바꿀, 기대, 되는, 유망, 기업, 카카오...
# 4     [증권사, 망치, 분석, 곳, 중, 곳, 최대, 실적, 예고, 카카오, 신, 사업,...
# ...                                                 ...
# 8422  [카카오, 온라인, 패션, 플랫폼, 지그재그, 자체, 브랜드, 개발, 착수, 한다,...
# 8423  [업계, 의견, 수렴, 해, 장기, 상생, 구현, 목표, 일, 성, 그치지, 않고,...
# 8424  [대리, 운전, 수수료, 개선, 이어, 새해, 상생, 플랫폼, 강화, 스타트업, 기...
# 8425  [코로나, 사태, 계기, 골프, 산업, 세대, 뿐, 아니라, 세대, 각광, 받으며,...
# 8426  [네이버, 카카오, 투자, 초기, 스타트업, 개사, 보니, 네이버, 곳, 중, 곳,...
#
# [8427 rows x 4 columns]

# %%
df.to_csv('/content/drive/MyDrive/2023년 10월-11월 프로젝트/토큰화 진행 및 불용어 처리/2021년 기사(완료).csv')
